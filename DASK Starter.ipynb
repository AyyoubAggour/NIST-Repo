# %%
#import dask.array as da

#images = da.ones((10000, 1000, 1000))
#images
# Out:
# dask.array<ones_like, shape=(10000, 1000, 1000), dtype=float64, chunksize=(255, 255, 255), chunktype=numpy.ndarray>

# %%
#import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()


df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

print(df.head())

import matplotlib.pyplot as plt

# Scatter plot of sepal length vs sepal width
plt.figure(figsize=(8, 6))
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=iris.target, cmap='viridis')
plt.title('Scatter plot of Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.colorbar(label='Species', ticks=range(3), orientation='horizontal', extend='both')
plt.show()

#simple scatter plot with each species of flower colored differently and plotted
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
import pandas as pd
import matplotlib.pyplot acccccbcflbvgiebivvfefchcjgnlukhhtcgvs plt
from sklearn.datasets import load_iris


iris = load_iris()


df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = iris.target_names[iris.target]

mean_values = df.groupby('species').mean()

# Plotting the line graph
plt.figure(figsize=(10, 2))

# Plot each feature's mean values across species
for feature in iris.feature_names:
    plt.plot(mean_values.index, mean_values[feature], marker='o', label=feature)

plt.title('Mean Feature Values across Iris Species')
plt.xlabel('Species')
plt.ylabel('Mean Value')
plt.legend()
plt.grid(True)
plt.xticks(rotation=5)
plt.tight_layout()

plt.show()

#mean of each feature of each flower
# Out:
#   Cell In[1], line 2
#     import matplotlib.pyplot acccccbcflbvgiebivvfefchcjgnlukhhtcgvs plt
#                              ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

df = pd.read_csv('iris.csv')

versicolor_df = df[df['species'] == 'versicolor']

max_values = versicolor_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].max()

print("Maximum values for versicolor:")
print(max_values)

print()

setosa_df = df[df['species'] == 'setosa']

meanSet = setosa_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].mean()

print("Setosa Mean Values")
print(meanSet)
# Out:
# Maximum values for versicolor:
# sepal_length    7.0
# sepal_width     3.4
# petal_length    5.1
# petal_width     1.8
# dtype: float64
#
# Setosa Mean Values
# sepal_length    5.006
# sepal_width     3.418
# petal_length    1.464
# petal_width     0.244
# dtype: float64

# %%
#DASK is used for parallel computing for df's that are to large
