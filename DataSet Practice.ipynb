# %%
from sklearn import svm
import pandas as pd



df = pd.read_csv('L0001.csv')
df.head()
# Out:
#       x     y      P    T  stepIndex  XVector  YVector  MPArea  ImageSize  \
# 0 -6.00  16.0  100.0  2.0       7750    0.009      0.0       0          0
# 1 -5.91  16.0  100.0  2.0       7760    0.009      0.0     127      14400
# 2 -5.82  16.0  100.0  2.0       7770    0.009      0.0     174      14400
# 3 -5.73  16.0  100.0  2.0       7780    0.009      0.0     195      14400
# 4 -5.64  16.0  100.0  2.0       7790    0.009      0.0     201      14400
#
#    SKImage-eqDiameter  ...  HoughTransform-b  HoughTransform-angle  \
# 0            0.000000  ...               NaN                   NaN
# 1           12.716187  ...          6.324555              2.574863
# 2           14.884343  ...          6.000000              1.570796
# 3           15.756958  ...          6.324555              2.976444
# 4           15.997536  ...          6.000000              1.570796
#
#    HoughTransform-fitness  boundary  distanceToBoundary  velocity  \
# ...

# %%
from sklearn.model_selection import train_test_split

all_x = df.drop(columns=['T', 'MPArea'])
all_y = df['MPArea']

X_train, X_test, y_train, y_test = train_test_split(all_x, all_y, test_size = 0.2)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (18947, 26) (4737, 26) (18947,) (4737,)

# %%
X_train
# Out:
#           x      y      P  stepIndex  XVector  YVector  ImageSize  \
# 15522  5.60  -4.84  195.0     255907    0.000    0.008      14400
# 8052   4.10   2.76  195.0     136531    0.000   -0.008      14400
# 12035  7.76  -7.00  100.0     203356   -0.009    0.000      14400
# 678    2.40  14.92  195.0      18715    0.000    0.008      14400
# 3817  -2.60  14.04  195.0      65105    0.000    0.008      14400
# ...     ...    ...    ...        ...      ...      ...        ...
# 2015   0.20  11.00  195.0      38685    0.000    0.008          0
# 7703   4.60   3.52  195.0     131541    0.000    0.008      14400
# 23173  6.90 -15.48  195.0     377693    0.000   -0.008      14400
# 7322   5.20   3.28  195.0     125931    0.000    0.008      14400
# 7710   4.60   4.08  195.0     131611    0.000    0.008      14400
#
#        SKImage-eqDiameter  SKImage-y0  SKImage-x0  ...  HoughTransform-b  \
# 15522           22.764193   70.614251   68.714988  ...          8.000000
# ...

# %%
X_train.describe().round(4)
# Out:
#                 x           y           P    stepIndex     XVector  \
# count  18947.0000  18947.0000  18947.0000   18947.0000  18947.0000
# mean       4.4810      0.0199    189.9760  196944.6237      0.0000
# std        5.1861     10.1773     21.2618  110828.5018      0.0017
# min       -6.0000    -16.0000    100.0000    7750.0000     -0.0090
# 25%        0.5000    -11.0000    195.0000   95930.0000      0.0000
# 50%        4.5000      2.0000    195.0000  192071.0000      0.0000
# 75%        8.5000     11.0000    195.0000  296993.0000      0.0000
# max       15.0000     16.0000    195.0000  385193.0000      0.0090
#
#           YVector   ImageSize  SKImage-eqDiameter  SKImage-y0  SKImage-x0  \
# count  18947.0000  18947.0000          18947.0000  18947.0000  18947.0000
# mean      -0.0001  14176.5557             21.2518     60.4793     66.3832
# std        0.0079   1779.8422              3.6102     11.0912      8.4014
# ...

# %%
X_test.describe().round(4)
# Out:
#                x          y          P    stepIndex    XVector    YVector  \
# count  4737.0000  4737.0000  4737.0000    4737.0000  4737.0000  4737.0000
# mean      4.5761    -0.0787   189.9061  197241.7764    -0.0000    -0.0001
# std       5.1732    10.1619    21.4026  110211.5714     0.0017     0.0079
# min      -6.0000   -16.0000   100.0000    7880.0000    -0.0090    -0.0090
# 25%       0.6000    -7.0000   195.0000  104546.0000     0.0000    -0.0080
# 50%       4.7000    -2.0400   195.0000  203236.0000     0.0000     0.0000
# 75%       8.6000     7.0000   195.0000  288477.0000     0.0000     0.0080
# max      15.0000    16.0000   195.0000  385183.0000     0.0090     0.0090
#
#         ImageSize  SKImage-eqDiameter  SKImage-y0  SKImage-x0  ...  \
# count   4737.0000           4737.0000   4737.0000   4737.0000  ...
# mean   14162.8879             21.1901     60.3606     66.3004  ...
# std     1832.7305              3.6928     11.2098      8.6442  ...
# ...

# %%
import numpy as np

np.random.seed(0)

df = pd.DataFrame({'x' : np.random.randn(500), 'MPArea' : np.random.randn(500)})

X = df['x']
y = df['MPArea']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 203)

from sklearn.linear_model import LinearRegression

X_train = np.array(X_train).reshape(-1,1)
X_train
# Out:
# array([[-0.74216502],
#        [-1.15942052],
#        [ 0.4105985 ],
#        [ 2.25930895],
#        [-0.4555325 ],
#        [-0.20829876],
#        [-0.10730528],
#        [ 0.09772497],
#        [ 0.1887786 ],
#        [ 0.07826018],
#        [-1.07993151],
#        [-0.72559738],
#        [ 0.72909056],
#        [ 1.73272119],
#        [ 1.36453185],
#        [-1.23482582],
#        [ 0.29823817],
#        [-0.15501009],
#        [-0.67246045],
#        [-0.36469354],
#        [ 0.370825  ],
#        [-0.6801782 ],
#        [-0.53945463],
#        [-2.09460307],
#        [ 0.46278226],
#        [ 0.04949498],
#        [ 2.2567235 ],
#        [-0.97110457],
#        [ 1.21114529],
#        [ 0.01747916],
#        [-0.15957344],
#        [ 2.3039167 ],
#        [-1.18063218],
#        [ 0.96939671],
#        [-0.4380743 ],
#        [-0.65102559],
#        [ 0.42625873],
#        [-1.18388064],
#        [ 0.15494743],
#        [-0.88241882],
#        [-1.53624369],
# ...

# %%
X_test = np.array(X_test).reshape(-1,1)
X_test.flatten()
# Out:
# array([-1.75589058, -1.6567151 , -0.21274028, -1.45436567, -0.40178094,
#        -0.70972797,  0.77325298, -1.07075262, -0.5028167 , -1.18885926,
#         0.93184837, -0.27567053,  0.3130677 ,  0.31694261, -0.20690368,
#         0.84436298,  1.84926373, -1.54079701, -0.31932842,  0.97663904,
#         0.67643329, -1.69810582, -0.23346666,  0.60884383, -0.46071979,
#         0.60631952, -0.85409574,  0.14206181, -0.80764849,  0.94942081,
#         0.88017891,  0.46566244, -0.89091508, -0.13010695, -1.61647419,
#        -0.19065349, -0.30901297, -0.04217145,  0.61037938, -0.49803245,
#        -0.02818223,  0.53924919,  0.84163126, -0.34791215, -0.89546656,
#        -0.80340966, -0.47965581,  0.77749036, -0.28688719, -0.76991607,
#         0.67229476,  1.86755799, -1.67600381, -1.60205766, -0.79311736,
#         0.61407937,  0.77179055, -0.63743703,  0.8005648 , -0.13288058,
#         0.1993002 ,  0.74718833,  0.2799246 , -0.46359597, -0.07392467,
# ...

# %%
clf = LinearRegression()

clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
c = clf.intercept_
c #y-int
# Out:
# -0.05414126101455083

# %%
m = clf.coef_
m #slope
# Out:
# array([-0.05130189])

# %%
y_pred_train = m*X_train + c
y_pred_train.flatten()
# Out:
# array([-1.60667930e-02,  5.33920243e-03, -7.52057401e-02, -1.70048080e-01,
#        -3.07715828e-02, -4.34551412e-02, -4.86362976e-02, -5.91547365e-02,
#        -6.38259598e-02, -5.81561559e-02,  1.26126610e-03, -1.69167443e-02,
#        -9.15449846e-02, -1.43033132e-01, -1.24144323e-01,  9.20763701e-03,
#        -6.94414429e-02, -4.61889503e-02, -1.96427693e-02, -3.54317930e-02,
#        -7.31652843e-02, -1.92468338e-02, -2.64662189e-02,  5.33158347e-02,
#        -7.78828652e-02, -5.66804471e-02, -1.69915441e-01, -4.32176146e-03,
#        -1.16275303e-01, -5.50379749e-02, -4.59548421e-02, -1.72336541e-01,
#         6.42740106e-03, -1.03873144e-01, -3.16672215e-02, -2.07424178e-02,
#        -7.60091394e-02,  6.59405300e-03, -6.20903568e-02, -8.87150812e-03,
#         2.46709431e-02, -5.91380736e-02, -1.45759792e-01,  5.78414276e-03,
#         1.68279240e-02, -7.24235306e-02, -7.04151549e-02, -5.33367391e-02,
# ...

# %%
clf.predict(X_train)
# Out:
# array([-1.60667930e-02,  5.33920243e-03, -7.52057401e-02, -1.70048080e-01,
#        -3.07715828e-02, -4.34551412e-02, -4.86362976e-02, -5.91547365e-02,
#        -6.38259598e-02, -5.81561559e-02,  1.26126610e-03, -1.69167443e-02,
#        -9.15449846e-02, -1.43033132e-01, -1.24144323e-01,  9.20763701e-03,
#        -6.94414429e-02, -4.61889503e-02, -1.96427693e-02, -3.54317930e-02,
#        -7.31652843e-02, -1.92468338e-02, -2.64662189e-02,  5.33158347e-02,
#        -7.78828652e-02, -5.66804471e-02, -1.69915441e-01, -4.32176146e-03,
#        -1.16275303e-01, -5.50379749e-02, -4.59548421e-02, -1.72336541e-01,
#         6.42740106e-03, -1.03873144e-01, -3.16672215e-02, -2.07424178e-02,
#        -7.60091394e-02,  6.59405300e-03, -6.20903568e-02, -8.87150812e-03,
#         2.46709431e-02, -5.91380736e-02, -1.45759792e-01,  5.78414276e-03,
#         1.68279240e-02, -7.24235306e-02, -7.04151549e-02, -5.33367391e-02,
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train, y_train)
plt.plot(X_train, y_pred_train, color='red')
plt.grid(True)

plt.xlabel('x')
plt.ylabel('MPArea')
plt.title('X vs Melt Pool Area')
plt.xticks(np.arange(-3, 4, 0.5))
plt.yticks(np.arange(-4,4,0.5))
plt.xticks(rotation=25) #rotate x ticks 25 degrees from the horizontal
plt.show()


#END PRODUCT - Linear Regression using 500 random data points comparing X and Melt Pool Area
