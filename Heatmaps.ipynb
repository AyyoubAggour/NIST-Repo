# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats

# %%
df = pd.read_csv('L0001.csv')

# %%
# Define the reference column
reference_column = 'x'

# Define the columns to compare
columns_to_compare = ['SKImage-a', 'SKImage-b', 'SKImage-x0', 'SKImage-y0', 'SKImage-angle', 'HoughTransform-a', 'HoughTransform-b']

# Create a DataFrame to store the correlation values
correlation_matrix = pd.DataFrame(index=columns_to_compare)

# Calculate the correlation with the reference column
correlations = [df[[reference_column, col]].corr().iloc[0, 1] for col in columns_to_compare]
correlation_matrix['Correlation'] = correlations

# %%
# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Heatmap of Correlations with x')
plt.show()

# %%
# Define the reference column
reference_column = 'y'

# Define the columns to compare
columns_to_compare = ['SKImage-a', 'SKImage-b', 'SKImage-x0', 'SKImage-y0', 'SKImage-angle', 'HoughTransform-a', 'HoughTransform-b']

# Create a DataFrame to store the correlation values
correlation_matrix = pd.DataFrame(index=columns_to_compare)

# Calculate the correlation with the reference column
correlations = [df[[reference_column, col]].corr().iloc[0, 1] for col in columns_to_compare]
correlation_matrix['Correlation'] = correlations

# %%
# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Heatmap of Correlations with y')
plt.show()

# %%
# Define the reference column
reference_column = 'P'

# Define the columns to compare
columns_to_compare = ['SKImage-a', 'SKImage-b', 'SKImage-x0', 'SKImage-y0', 'SKImage-angle', 'HoughTransform-a', 'HoughTransform-b']

# Create a DataFrame to store the correlation values
correlation_matrix = pd.DataFrame(index=columns_to_compare)

# Calculate the correlation with the reference column
correlations = [df[[reference_column, col]].corr().iloc[0, 1] for col in columns_to_compare]
correlation_matrix['Correlation'] = correlations

# %%
# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Heatmap of Correlations with P')
plt.show()
